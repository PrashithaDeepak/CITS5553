# %%
import os
import re

# Define a function to clean text
def clean_text(text):
    # Remove numbers and 'n' characters when standalone
    cleaned_text = re.sub(r'\d+', '', text)  # Remove numbers
    cleaned_text = re.sub(r'\bn\b', ' ', cleaned_text)  # Remove standalone 'n' characters
    cleaned_text = re.sub(r'[^\w\s]', '', cleaned_text)  # Remove punctuation
    return cleaned_text

# Specify the path to the "postprocessed" folder
folder_path = "postprocessed"

# Loop through all text files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".txt"):
        file_path = os.path.join(folder_path, filename)
        with open(file_path, "r") as file:
            text = file.read()
            cleaned_text = clean_text(text)
        
        # Write the cleaned text back to the file
        with open(file_path, "w") as file:
            file.write(cleaned_text)

print("Text files cleaned successfully.")
# Out:
# Text files cleaned successfully.

# %%
import os
from sklearn.feature_extraction.text import TfidfVectorizer

# Specify the path to the "postprocessed" folder
folder_path = "postprocessed"

# List to store the cleaned text from all files
documents = []

# Loop through all text files in the folder and collect the cleaned text
for filename in os.listdir(folder_path):
    if filename.endswith(".txt"):
        file_path = os.path.join(folder_path, filename)
        with open(file_path, "r") as file:
            text = file.read()
            documents.append(text)

# Initialize the TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Fit and transform the documents to calculate TF-IDF
tfidf_matrix = tfidf_vectorizer.fit_transform(documents)

# Get the feature names (words)
feature_names = tfidf_vectorizer.get_feature_names_out()

# Create a dictionary to store TF-IDF scores for each word
word_tfidf_scores = {}
for i, feature in enumerate(feature_names):
    word_tfidf_scores[feature] = tfidf_matrix[0, i]

# Print TF-IDF scores for each word in the first document
for word, score in sorted(word_tfidf_scores.items(), key=lambda x: x[1], reverse=True):
    print(f"{word}: {score:.4f}")
# Out:
# figure: 0.3537
# plan: 0.3537
# table: 0.2535
# geology: 0.2298
# exploration: 0.2199
# project: 0.1977
# status: 0.1950
# bulong: 0.1753
# knp: 0.1753
# physiography: 0.1753
# scoping: 0.1753
# study: 0.1753
# client: 0.1596
# multi: 0.1596
# rom: 0.1596
# data: 0.1587
# containing: 0.1485
# cd: 0.1399
# bibliography: 0.1329
# tmi: 0.1329
# previous: 0.1296
# interpreted: 0.1269
# conclusion: 0.1217
# tenement: 0.1155
# surface: 0.1131
# on: 0.1095
# interpretation: 0.1061
# digital: 0.1030
# review: 0.1002
# summary: 0.0950
# appendix: 0.0927
# aeromagnetic: 0.0905
# activities: 0.0864
# index: 0.0827
# recommendations: 0.0778
# references: 0.0626
# regional: 0.0542
# and: 0.0495
# location: 0.0440
# abd: 0.0000
# acacia: 0.0000
# access: 0.0000
# acquisitions: 0.0000
# across: 0.0000
# activity: 0.0000
# activties: 0.0000
# adjacent: 0.0000
# adjoins: 0.0000
# aeromagnetics: 0.0000
# after: 0.0000
# airborne: 0.0000
# al: 0.0000
# all: 0.0000
# amoco: 0.0000
# an: 0.0000
# analyses: 0.0000
# analysis: 0.0000
# annual: 0.0000
# anomalies: 0.0000
# anomalism: 0.0000
# anomalous: 0.0000
# anomaly: 0.0000
# api: 0.0000
# appendices: 0.0000
# applications: 0.0000
# approach: 0.0000
# archaean: 0.0000
# are: 0.0000
# area: 0.0000
# areas: 0.0000
# as: 0.0000
# ash: 0.0000
# ashburton: 0.0000
# assa: 0.0000
# assay: 0.0000
# assays: 0.0000
# assessment: 0.0000
# associates: 0.0000
# association: 0.0000
# at: 0.0000
# attached: 0.0000
# attachments: 0.0000
# au: 0.0000
# august: 0.0000
# aurora: 0.0000
# aust: 0.0000
# australia: 0.0000
# available: 0.0000
# background: 0.0000
# balagundi: 0.0000
# bangemall: 0.0000
# baracus: 0.0000
# basalt: 0.0000
# base: 0.0000
# basin: 0.0000
# bbox: 0.0000
# been: 0.0000
# bellary: 0.0000
# below: 0.0000
# belt: 0.0000
# bencubbin: 0.0000
# best: 0.0000
# blaze: 0.0000
# bleg: 0.0000
# block: 0.0000
# blowings: 0.0000
# boorara: 0.0000
# booylgoo: 0.0000
# bore: 0.0000
# boreholes: 0.0000
# bores: 0.0000
# boundary: 0.0000
# budget: 0.0000
# bulk: 0.0000
# buxton: 0.0000
# by: 0.0000
# calcrete: 0.0000
# calculations: 0.0000
# capricorn: 0.0000
# carboniferous: 0.0000
# carried: 0.0000
# channel: 0.0000
# checking: 0.0000
# chip: 0.0000
# christmas: 0.0000
# circulation: 0.0000
# classification: 0.0000
# clearances: 0.0000
# co: 0.0000
# cobalt: 0.0000
# codes: 0.0000
# coil: 0.0000
# cola: 0.0000
# collar: 0.0000
# colour: 0.0000
# column: 0.0000
# combined: 0.0000
# commitments: 0.0000
# compilation: 0.0000
# completed: 0.0000
# conclusions: 0.0000
# conducted: 0.0000
# conductor: 0.0000
# considered: 0.0000
# consolidation: 0.0000
# constitutes: 0.0000
# consultants: 0.0000
# contents: 0.0000
# contiguous: 0.0000
# contour: 0.0000
# contours: 0.0000
# coolcalalaya: 0.0000
# copper: 0.0000
# corp: 0.0000
# cosmo: 0.0000
# crcleme: 0.0000
# credo: 0.0000
# creek: 0.0000
# crop: 0.0000
# cross: 0.0000
# cu: 0.0000
# cullen: 0.0000
# current: 0.0000
# curtin: 0.0000
# darkan: 0.0000
# databases: 0.0000
# datasets: 0.0000
# date: 0.0000
# ddh: 0.0000
# dec: 0.0000
# deformation: 0.0000
# density: 0.0000
# department: 0.0000
# deposits: 0.0000
# derivative: 0.0000
# description: 0.0000
# deserts: 0.0000
# detail: 0.0000
# details: 0.0000
# development: 0.0000
# dhem: 0.0000
# dhmmr: 0.0000
# diagram: 0.0000
# diamond: 0.0000
# discussion: 0.0000
# discussions: 0.0000
# distribution: 0.0000
# disturbing: 0.0000
# doc: 0.0000
# domain: 0.0000
# domains: 0.0000
# dominant: 0.0000
# done: 0.0000
# down: 0.0000
# downhole: 0.0000
# drill: 0.0000
# drilled: 0.0000
# drillhole: 0.0000
# drillholes: 0.0000
# drilling: 0.0000
# dry: 0.0000
# duplicate: 0.0000
# during: 0.0000
# eastern: 0.0000
# either: 0.0000
# el: 0.0000
# electronic: 0.0000
# elevation: 0.0000
# em: 0.0000
# end: 0.0000
# environment: 0.0000
# environmental: 0.0000
# environs: 0.0000
# estimates: 0.0000
# estimations: 0.0000
# et: 0.0000
# events: 0.0000
# expenditure: 0.0000
# exploratory: 0.0000
# extensional: 0.0000
# facility: 0.0000
# felsic: 0.0000
# field: 0.0000
# fig: 0.0000
# figures: 0.0000
# file: 0.0000
# files: 0.0000
# financial: 0.0000
# find: 0.0000
# five: 0.0000
# fixed: 0.0000
# follows: 0.0000
# for: 0.0000
# form: 0.0000
# fortescue: 0.0000
# four: 0.0000
# from: 0.0000
# further: 0.0000
# future: 0.0000
# general: 0.0000
# generation: 0.0000
# geoa: 0.0000
# geochemical: 0.0000
# geochemistry: 0.0000
# geological: 0.0000
# geomorphology: 0.0000
# geophysical: 0.0000
# geophysics: 0.0000
# geoscience: 0.0000
# gifford: 0.0000
# glenview: 0.0000
# go: 0.0000
# gold: 0.0000
# goldfield: 0.0000
# goldfields: 0.0000
# grainsize: 0.0000
# gram: 0.0000
# granted: 0.0000
# gravity: 0.0000
# greenstone: 0.0000
# greyscale: 0.0000
# grid: 0.0000
# ground: 0.0000
# group: 0.0000
# gswa: 0.0000
# hamersley: 0.0000
# hammer: 0.0000
# hardcopy: 0.0000
# has: 0.0000
# have: 0.0000
# hays: 0.0000
# heritage: 0.0000
# hill: 0.0000
# hills: 0.0000
# hillside: 0.0000
# historic: 0.0000
# historical: 0.0000
# history: 0.0000
# holding: 0.0000
# hole: 0.0000
# holes: 0.0000
# hunter: 0.0000
# igneous: 0.0000
# ii: 0.0000
# iii: 0.0000
# image: 0.0000
# imagery: 0.0000
# in: 0.0000
# including: 0.0000
# information: 0.0000
# interest: 0.0000
# international: 0.0000
# interpreation: 0.0000
# intersections: 0.0000
# introduction: 0.0000
# investigations: 0.0000
# iron: 0.0000
# is: 0.0000
# island: 0.0000
# isometric: 0.0000
# isosurface: 0.0000
# it: 0.0000
# item: 0.0000
# iv: 0.0000
# jabiluka: 0.0000
# jackson: 0.0000
# jaguar: 0.0000
# joint: 0.0000
# june: 0.0000
# kalgoorlie: 0.0000
# kersey: 0.0000
# kilometres: 0.0000
# kinematic: 0.0000
# king: 0.0000
# kms: 0.0000
# korab: 0.0000
# lag: 0.0000
# land: 0.0000
# landowner: 0.0000
# landsat: 0.0000
# late: 0.0000
# leachwell: 0.0000
# leasing: 0.0000
# lever: 0.0000
# licence: 0.0000
# licences: 0.0000
# licenses: 0.0000
# limited: 0.0000
# line: 0.0000
# lines: 0.0000
# list: 0.0000
# listed: 0.0000
# listing: 0.0000
# lithology: 0.0000
# local: 0.0000
# locality: 0.0000
# located: 0.0000
# locations: 0.0000
# lodged: 0.0000
# logged: 0.0000
# logging: 0.0000
# looking: 0.0000
# loop: 0.0000
# loops: 0.0000
# lower: 0.0000
# ltd: 0.0000
# macdonald: 0.0000
# magnetic: 0.0000
# magnetics: 0.0000
# magneto: 0.0000
# management: 0.0000
# map: 0.0000
# mapping: 0.0000
# martin: 0.0000
# maxlow: 0.0000
# maynard: 0.0000
# me: 0.0000
# menzies: 0.0000
# metal: 0.0000
# metals: 0.0000
# metalurgical: 0.0000
# method: 0.0000
# methods: 0.0000
# metres: 0.0000
# metric: 0.0000
# middle: 0.0000
# mile: 0.0000
# mindax: 0.0000
# mineral: 0.0000
# mineralisation: 0.0000
# mineralization: 0.0000
# mineralogy: 0.0000
# minerals: 0.0000
# mines: 0.0000
# mining: 0.0000
# mithril: 0.0000
# mltem: 0.0000
# mmi: 0.0000
# model: 0.0000
# modelling: 0.0000
# montana: 0.0000
# morelands: 0.0000
# mory: 0.0000
# moving: 0.0000
# ms: 0.0000
# mt: 0.0000
# mzm: 0.0000
# native: 0.0000
# ne: 0.0000
# near: 0.0000
# nell: 0.0000
# new: 0.0000
# newbery: 0.0000
# nickel: 0.0000
# nl: 0.0000
# no: 0.0000
# noaa: 0.0000
# nominal: 0.0000
# north: 0.0000
# northern: 0.0000
# northwest: 0.0000
# number: 0.0000
# numbers: 0.0000
# occurrences: 0.0000
# oct: 0.0000
# october: 0.0000
# of: 0.0000
# one: 0.0000
# only: 0.0000
# open: 0.0000
# operations: 0.0000
# operators: 0.0000
# or: 0.0000
# ordered: 0.0000
# ore: 0.0000
# orientated: 0.0000
# orogen: 0.0000
# other: 0.0000
# out: 0.0000
# outcamp: 0.0000
# outcrop: 0.0000
# outline: 0.0000
# over: 0.0000
# overlain: 0.0000
# overlaying: 0.0000
# page: 0.0000
# paraburdoo: 0.0000
# part: 0.0000
# partial: 0.0000
# pdf: 0.0000
# performed: 0.0000
# period: 0.0000
# permo: 0.0000
# peter: 0.0000
# phosphate: 0.0000
# photo: 0.0000
# physical: 0.0000
# pilbara: 0.0000
# planned: 0.0000
# plans: 0.0000
# plates: 0.0000
# plutonic: 0.0000
# potassium: 0.0000
# potential: 0.0000
# ppb: 0.0000
# ppm: 0.0000
# pre: 0.0000
# preparation: 0.0000
# primary: 0.0000
# processing: 0.0000
# profile: 0.0000
# program: 0.0000
# programme: 0.0000
# projects: 0.0000
# property: 0.0000
# proposed: 0.0000
# prospect: 0.0000
# prospecting: 0.0000
# prospective: 0.0000
# prospectivity: 0.0000
# prospects: 0.0000
# prosperity: 0.0000
# proterozoic: 0.0000
# proven: 0.0000
# province: 0.0000
# pty: 0.0000
# quickbird: 0.0000
# rab: 0.0000
# radiometric: 0.0000
# radiometrics: 0.0000
# range: 0.0000
# rc: 0.0000
# rdms: 0.0000
# re: 0.0000
# reccomendations: 0.0000
# recent: 0.0000
# recommendation: 0.0000
# recommended: 0.0000
# recommentations: 0.0000
# reconnaissance: 0.0000
# recovery: 0.0000
# red: 0.0000
# regeonal: 0.0000
# region: 0.0000
# regolith: 0.0000
# rehabilitation: 0.0000
# reinterpretation: 0.0000
# relative: 0.0000
# relinquishment: 0.0000
# rep: 0.0000
# report: 0.0000
# reporting: 0.0000
# reports: 0.0000
# reprocessing: 0.0000
# resampling: 0.0000
# reserve: 0.0000
# resistivity: 0.0000
# resource: 0.0000
# resources: 0.0000
# respect: 0.0000
# responsible: 0.0000
# results: 0.0000
# revenge: 0.0000
# reverse: 0.0000
# revision: 0.0000
# rgb: 0.0000
# rock: 0.0000
# rocks: 0.0000
# sabbath: 0.0000
# safety: 0.0000
# salt: 0.0000
# samedan: 0.0000
# sample: 0.0000
# samples: 0.0000
# sampling: 0.0000
# satellite: 0.0000
# sb: 0.0000
# scale: 0.0000
# schematic: 0.0000
# schwann: 0.0000
# scope: 0.0000
# scrapes: 0.0000
# section: 0.0000
# security: 0.0000
# sediment: 0.0000
# seismic: 0.0000
# services: 0.0000
# sets: 0.0000
# setting: 0.0000
# shafts: 0.0000
# shaw: 0.0000
# sheet: 0.0000
# sheets: 0.0000
# shotline: 0.0000
# shotlines: 0.0000
# showing: 0.0000
# siberia: 0.0000
# significant: 0.0000
# siliclastic: 0.0000
# similar: 0.0000
# simplified: 0.0000
# site: 0.0000
# sog: 0.0000
# soil: 0.0000
# solid: 0.0000
# source: 0.0000
# south: 0.0000
# splitting: 0.0000
# srtmm: 0.0000
# st: 0.0000
# star: 0.0000
# station: 0.0000
# stations: 0.0000
# storage: 0.0000
# strain: 0.0000
# stratigraphic: 0.0000
# stratigraphy: 0.0000
# stream: 0.0000
# structural: 0.0000
# structure: 0.0000
# stuart: 0.0000
# studies: 0.0000
# sub: 0.0000
# submitted: 0.0000
# supply: 0.0000
# sura: 0.0000
# surfa: 0.0000
# surrounding: 0.0000
# survey: 0.0000
# surveying: 0.0000
# surveys: 0.0000
# swager: 0.0000
# sweet: 0.0000
# syndicated: 0.0000
# tables: 0.0000
# tailings: 0.0000
# target: 0.0000
# targets: 0.0000
# technical: 0.0000
# ten: 0.0000
# tenements: 0.0000
# tenure: 0.0000
# term: 0.0000
# terrain: 0.0000
# terrane: 0.0000
# territory: 0.0000
# test: 0.0000
# tests: 0.0000
# text: 0.0000
# th: 0.0000
# thaduna: 0.0000
# the: 0.0000
# thematic: 0.0000
# this: 0.0000
# thorium: 0.0000
# time: 0.0000
# title: 0.0000
# tm: 0.0000
# to: 0.0000
# tonnage: 0.0000
# topographic: 0.0000
# topography: 0.0000
# track: 0.0000
# trending: 0.0000
# troy: 0.0000
# tulloch: 0.0000
# two: 0.0000
# txt: 0.0000
# type: 0.0000
# typical: 0.0000
# uce: 0.0000
# ultramafic: 0.0000
# unconformably: 0.0000
# unconformity: 0.0000
# underground: 0.0000
# undertaken: 0.0000
# units: 0.0000
# unorthwest: 0.0000
# update: 0.0000
# upon: 0.0000
# uranium: 0.0000
# us: 0.0000
# use: 0.0000
# utilities: 0.0000
# values: 0.0000
# vegetation: 0.0000
# ventures: 0.0000
# verification: 0.0000
# vertical: 0.0000
# view: 0.0000
# visit: 0.0000
# volcanic: 0.0000
# volcaniclastic: 0.0000
# volume: 0.0000
# wa: 0.0000
# wadg: 0.0000
# wadl: 0.0000
# wads: 0.0000
# wallbrook: 0.0000
# wasg: 0.0000
# wasl: 0.0000
# water: 0.0000
# webb: 0.0000
# weighted: 0.0000
# weld: 0.0000
# well: 0.0000
# west: 0.0000
# western: 0.0000
# wgs: 0.0000
# which: 0.0000
# wilson: 0.0000
# wiluna: 0.0000
# with: 0.0000
# within: 0.0000
# woolarry: 0.0000
# work: 0.0000
# workings: 0.0000
# ws: 0.0000
# yampi: 0.0000
# yaringa: 0.0000
# year: 0.0000
# yeelirrie: 0.0000
# yerilla: 0.0000
# yilgarn: 0.0000
